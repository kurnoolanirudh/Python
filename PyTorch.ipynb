# %%
! pip install torch torchvision --index-url https://download.pytorch.org/whl/rocm6.4
# Out:
# Looking in indexes: https://download.pytorch.org/whl/rocm6.4
# Collecting torch
#   Downloading https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/rocm6.4/torchvision-0.23.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting filelock (from torch)
#   Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.13/site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Using cached https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting pytorch-triton-rocm==3.4.0 (from torch)
#   Downloading https://download.pytorch.org/whl/pytorch_triton_rocm-3.4.0-cp313-cp313-linux_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from torchvision) (2.3.3)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading https://download.pytorch.org/whl/pillow-11.0.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (3607.0 MB)
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/3.6 GB 4.2 MB/s eta 0:12:59
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (334.0 MB/3607.0 MB, attempt 1)
# Resuming download https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (334.0 MB/3607.0 MB)
#    ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/3.6 GB 1.2 MB/s eta 0:31:400m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1333.0 MB/3607.0 MB, attempt 2)
# Resuming download https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (1333.0 MB/3607.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 2.3/3.6 GB 3.4 MB/s eta 0:06:230m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2326.0 MB/3607.0 MB, attempt 3)
# Resuming download https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (2326.0 MB/3607.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 3.0/3.6 GB 674.3 kB/s eta 0:14:15
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (3030.9 MB/3607.0 MB, attempt 4)
# Resuming download https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (3030.9 MB/3607.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 3.1/3.6 GB 1.7 MB/s eta 0:05:13:100m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (3079.4 MB/3607.0 MB, attempt 5)
# Resuming download https://download.pytorch.org/whl/rocm6.4/torch-2.8.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (3079.4 MB/3607.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 GB 3.6 MB/s  0:02:33 eta 0:00:010:00:27
# Downloading https://download.pytorch.org/whl/pytorch_triton_rocm-3.4.0-cp313-cp313-linux_x86_64.whl (258.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.7/258.7 MB 3.6 MB/s  0:01:17 eta 0:00:010:00:02
# Downloading https://download.pytorch.org/whl/rocm6.4/torchvision-0.23.0%2Brocm6.4-cp313-cp313-manylinux_2_28_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 2.3 MB/s  0:00:022.4 MB/s eta 0:00:01:01
# Downloading https://download.pytorch.org/whl/pillow-11.0.0-cp313-cp313-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 4.4 MB/s  0:00:00m 5.5 MB/s eta 0:00:01
# Using cached https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
# Installing collected packages: mpmath, sympy, pytorch-triton-rocm, pillow, networkx, fsspec, filelock, torch, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [torchvision]7m━━━━ 8/9 [torchvision]on-rocm]
# Successfully installed filelock-3.13.1 fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 pillow-11.0.0 pytorch-triton-rocm-3.4.0 sympy-1.13.3 torch-2.8.0+rocm6.4 torchvision-0.23.0+rocm6.4

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name()
# Out:
# 'AMD Radeon Graphics'
